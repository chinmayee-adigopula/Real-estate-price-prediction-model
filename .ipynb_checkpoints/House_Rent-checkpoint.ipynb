# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio


from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv("C:\\Users\\msafr\\Downloads\\house price prediction\\House_Rent_Dataset.csv", parse_dates=["Posted On"])
df.head()
# Out:
#    Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0 2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1 2022-05-13    2  20000   800       1 out of 3   Super Area
# 2 2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3 2022-07-04    2  10000   800       1 out of 2   Super Area
# 4 2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %% [markdown]
# ## Data Cleaning

# %%
df["Rental Floor"] = df["Floor"].apply(lambda x: x.split(" out of ")[0])
df["Total Number of Floor"] = df["Floor"].apply(lambda x: x.split(" out of ")[-1])
df.sample(5)
# Out:
#       Posted On  BHK   Rent  Size         Floor    Area Type  \
# 693  2022-06-13    2  50000   850  10 out of 23  Carpet Area
# 2279 2022-07-07    1   8500   300    2 out of 3   Super Area
# 969  2022-06-30    2  32000   550    4 out of 7  Carpet Area
# 4387 2022-06-25    2  12000  1000    5 out of 6   Super Area
# 4148 2022-06-10    1  10000   500    1 out of 3   Super Area
#
#                          Area Locality       City Furnishing Status  \
# 693                          Film City     Mumbai    Semi-Furnished
# 2279                      Bommanahalli  Bangalore    Semi-Furnished
# 969   Shiv Ganga Apartment, Malad West     Mumbai    Semi-Furnished
# 4387                        Upperpally  Hyderabad    Semi-Furnished
# 4148                 Khairatabad, NH 7  Hyderabad    Semi-Furnished
#
#       Tenant Preferred  Bathroom Point of Contact Rental Floor  \
# 693   Bachelors/Family         2    Contact Agent           10
# 2279  Bachelors/Family         1    Contact Owner            2
# 969   Bachelors/Family         2    Contact Agent            4
# 4387  Bachelors/Family         2    Contact Owner            5
# 4148  Bachelors/Family         1    Contact Owner            1
#
#      Total Number of Floor
# 693                     23
# 2279                     3
# 969                      7
# 4387                     6
# 4148                     3

# %%
df["Rental Floor"].unique()
# Out:
# array(['Ground', '1', '2', '4', '3', '5', '7', '8', 'Upper Basement',
#        '11', 'Lower Basement', '6', '14', '43', '13', '18', '17', '9',
#        '19', '60', '34', '12', '26', '25', '53', '16', '10', '39', '32',
#        '47', '28', '20', '15', '65', '40', '37', '22', '21', '30', '35',
#        '33', '44', '41', '46', '27', '45', '48', '50', '24', '23', '29',
#        '49', '36', '76'], dtype=object)

# %%
df["Total Number of Floor"].unique()
# Out:
# array(['2', '3', '1', '4', '5', '14', '8', '6', '19', '10', '7', '13',
#        '78', '18', '12', '24', '31', '21', '23', '20', '9', '22', '58',
#        '16', '66', '48', '40', '44', '42', '41', '60', '32', '30', '29',
#        '89', '15', '11', '28', '17', '45', '35', '75', '38', '51', '43',
#        '25', '27', '26', '76', '36', '37', '55', '68', '77', '50', '59',
#        '62', '39', '52', '54', '33', '46', '85', '71', '81', '34',
#        'Ground'], dtype=object)

# %%
df["Rental Floor"] = df["Rental Floor"].replace(["Ground", "Upper Basement", "Lower Basement"], [0, -1, -2]).astype(int)
df["Total Number of Floor"] = df["Total Number of Floor"].replace("Ground", 0).astype(int)
df.drop(columns="Floor", inplace=True)
df.sample()
# Out:
#       Posted On  BHK   Rent  Size    Area Type           Area Locality  \
# 2056 2022-06-12    2  15000  1050  Carpet Area  Mcechs Layout, Jakkuru
#
#            City Furnishing Status Tenant Preferred  Bathroom Point of Contact  \
# 2056  Bangalore    Semi-Furnished           Family         2    Contact Owner
#
#       Rental Floor  Total Number of Floor
# 2056             2                      2

# %%
num_var = ["Rental Floor", "Total Number of Floor"]
fig, axes = plt.subplots(1, 2, figsize=(12,7))
for num, ax in zip(num_var, axes.flatten()):
    sns.histplot(x=num, data=df, ax=ax)

# %% [markdown]
# ### Category variabel

# %%
cat_var = ["Area Type", "Furnishing Status", "Tenant Preferred", "Point of Contact"]
fig, axes = plt.subplots(2, 2, figsize=(12,10))
for cat, ax in zip(cat_var, axes.flatten()):
    sns.countplot(x=cat, data=df, ax=ax)

# %%
df.replace(to_replace=["Built Area", "Contact Builder"], 
           value=["Super Area", "Contact Owner"], inplace=True)

# %%
area_mean = df.query("BHK + Bathroom == 4").groupby("Area Type", as_index=False).mean()
area_mean
# Out:
# C:\Users\msafr\AppData\Local\Temp\ipykernel_11848\3345422993.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   area_mean = df.query("BHK + Bathroom == 4").groupby("Area Type", as_index=False).mean()
#      Area Type       BHK          Rent        Size  Bathroom  Rental Floor  \
# 0  Carpet Area  2.012484  34236.268414  838.001248  1.987516      4.308365
# 1   Super Area  2.017787  15827.197628  933.087945  1.982213      1.777668
#
#    Total Number of Floor
# 0               8.796504
# 1               3.970356

# %%
carpet_area_size = area_mean.loc[0, "Size"]
super_area_size = area_mean.loc[1, "Size"]
area_per_multi = (super_area_size - carpet_area_size) / carpet_area_size + 1 #area prcentage multiplier
area_per_multi
# Out:
# 1.1134684422029848

# %%
fixed_size = df.query("`Area Type` == 'Carpet Area'")["Size"].apply(lambda x: x * area_per_multi)
df["Fixed Size"] = np.round(fixed_size, 2)
df["Fixed Size"].fillna(df["Size"], inplace=True)
df.head()
# Out:
#    Posted On  BHK   Rent  Size    Area Type             Area Locality  \
# 0 2022-05-18    2  10000  1100   Super Area                    Bandel
# 1 2022-05-13    2  20000   800   Super Area  Phool Bagan, Kankurgachi
# 2 2022-05-16    2  17000  1000   Super Area   Salt Lake City Sector 2
# 3 2022-07-04    2  10000   800   Super Area               Dumdum Park
# 4 2022-05-09    2   7500   850  Carpet Area             South Dum Dum
#
#       City Furnishing Status  Tenant Preferred  Bathroom Point of Contact  \
# 0  Kolkata       Unfurnished  Bachelors/Family         2    Contact Owner
# 1  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 2  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 3  Kolkata       Unfurnished  Bachelors/Family         1    Contact Owner
# 4  Kolkata       Unfurnished         Bachelors         1    Contact Owner
#
#    Rental Floor  Total Number of Floor  Fixed Size
# 0             0                      2     1100.00
# 1             1                      3      800.00
# 2             1                      3     1000.00
# 3             1                      2      800.00
# 4             1                      2      946.45

# %%
df.drop(columns=["Area Locality", "Posted On"], inplace=True)

# %%
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'xy'}]])

fig.add_trace(go.Pie(labels = df["Point of Contact"] ,name="Point of Contact", textinfo='percent+label', textposition='inside', marker=dict(line=dict(color='white', width=1))),row=1, col=1)
fig.add_trace(go.Histogram(x = df["Point of Contact"],name="Point of Contact"),row=1, col=2)

fig.update_layout(showlegend=False, title="Point of Contact", title_x=.5)

fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Histogram(x = df["City"], name="City", texttemplate="%{y}")).update_xaxes(categoryorder='total descending')
fig.update_layout(title="Total Number of Rental Houses in Cities", title_x=.5)
fig.show()

# %% [markdown]
# `Square Feet Rent` is a standardized measure used to calculate the rental cost or price of a property per unit area in square feet. This concept is commonly used in the real estate industry to simplify rental cost comparisons between properties of different sizes.
#
# Square Feet Rent = Total Rental Cost / Total Area (in square feet)

# %%
square_feet_rent = df["Rent"]/df["Fixed Size"]
df["Square Feet Rent"] = np.round(square_feet_rent, 2)
df.head()
# Out:
#    BHK   Rent  Size    Area Type     City Furnishing Status  Tenant Preferred  \
# 0    2  10000  1100   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 1    2  20000   800   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 2    2  17000  1000   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 3    2  10000   800   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 4    2   7500   850  Carpet Area  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact  Rental Floor  Total Number of Floor  Fixed Size  \
# 0         2    Contact Owner             0                      2     1100.00
# 1         1    Contact Owner             1                      3      800.00
# 2         1    Contact Owner             1                      3     1000.00
# 3         1    Contact Owner             1                      2      800.00
# 4         1    Contact Owner             1                      2      946.45
#
#    Square Feet Rent
# 0              9.09
# 1             25.00
# 2             17.00
# 3             12.50
# 4              7.92

# %%
df = df.drop(df.query("`Square Feet Rent` > 57.94").index)

# %%
df.drop(columns = ["Size", "Area Type"], inplace = True)

# %% [markdown]
# ## Correlation Matrix

# %%
sns.heatmap(df.corr(), annot=True);
# Out:
# C:\Users\msafr\AppData\Local\Temp\ipykernel_11848\4095736044.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# ## Build Model

# %%
X = df.drop(columns='Rent')
y = df['Rent']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=True, random_state=101)
X_train.shape, X_test.shape
# Out:
# ((2940, 10), (980, 10))

# %%
X_train.head()
# Out:
#       BHK       City Furnishing Status  Tenant Preferred  Bathroom  \
# 2573    3      Delhi    Semi-Furnished         Bachelors         3
# 443     2    Kolkata    Semi-Furnished  Bachelors/Family         1
# 1107    1     Mumbai    Semi-Furnished  Bachelors/Family         1
# 1919    1  Bangalore       Unfurnished  Bachelors/Family         1
# 332     1    Kolkata       Unfurnished  Bachelors/Family         1
#
#      Point of Contact  Rental Floor  Total Number of Floor  Fixed Size  \
# 2573    Contact Agent             1                      1     1892.90
# 443     Contact Owner             1                      2      556.73
# 1107    Contact Agent             0                      7      367.44
# 1919    Contact Owner             3                      3      334.04
# 332     Contact Owner             1                      1      400.00
#
#       Square Feet Rent
# 2573             27.47
# 443              10.78
# 1107             46.27
# 1919             20.96
# 332              16.25

# %% [markdown]
# #### XGBRegressor

# %%
cat_pipe = Pipeline([("encode", OneHotEncoder(handle_unknown="ignore"))])
num_pipe = Pipeline([("scaler", StandardScaler())])

preprocessor = ColumnTransformer([
    ("numeric", num_pipe, [0,4,6,7,8,9]),
    ("categoric", cat_pipe, [1,2,3,5])
])

pipeline_xgbr = Pipeline([
    ('prep', preprocessor),
    ('algo', XGBRegressor())
])

pipeline_xgbr.fit(X_train,y_train)
y_pred = pipeline_xgbr.predict(X_test)
print(f"Score    : {r2_score(y_test, y_pred)}")
print(f"mae      : {mean_absolute_error(y_test, y_pred)}")
print(f"root mse : {np.sqrt(mean_squared_error(y_test, y_pred))}")
# Out:
# Score    : 0.9785805768098474
# mae      : 800.0709126375159
# root mse : 3173.913773458429

# %% [markdown]
# #### LGBMRegressor

# %%
cat_pipe = Pipeline([("encode", OneHotEncoder(handle_unknown="ignore"))])
num_pipe = Pipeline([("scaler", StandardScaler())])

preprocessor = ColumnTransformer([
    ("numeric", num_pipe, [0,4,6,7,8,9]),
    ("categoric", cat_pipe, [1,2,3,5])
])

pipeline_lgbm = Pipeline([
    ('prep', preprocessor),
    ('algo', LGBMRegressor())
])

pipeline_lgbm.fit(X_train,y_train)
y_pred = pipeline_lgbm.predict(X_test)
print(f"Score    : {r2_score(y_test, y_pred)}")
print(f"mae      : {mean_absolute_error(y_test, y_pred)}")
print(f"root mse : {np.sqrt(mean_squared_error(y_test, y_pred))}")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000962 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 619
# [LightGBM] [Info] Number of data points in the train set: 2940, number of used features: 20
# [LightGBM] [Info] Start training from score 20943.766667
# Score    : 0.9862029550152648
# mae      : 662.0601750381039
# root mse : 2547.3245339839686

# %% [markdown]
# ## Save Model

# %%
import pickle


with open("lgbm_model.pkl", "wb") as f:
    pickle.dump(pipeline_lgbm, f)
